# %%
import pandas as pd

# %%
df_company = pd.read_csv("../Data/ai_company_adoption.csv")

# %%
df_company.head()
# Out:
#    response_id  company_id  survey_year quarter country  region   industry  \
# 0            1  COMP-00001         2023      Q1   Italy  Europe  Education
# 1            2  COMP-00001         2023      Q2   Italy  Europe  Education
# 2            3  COMP-00001         2023      Q3   Italy  Europe  Education
# 3            4  COMP-00001         2023      Q4   Italy  Europe  Education
# 4            5  COMP-00001         2024      Q1   Italy  Europe  Education
#
#   company_size  num_employees  annual_revenue_usd_millions  ...  \
# 0      Startup             57                        48.31  ...
# 1      Startup             57                        48.31  ...
# 2      Startup             57                        48.31  ...
# 3      Startup             57                        48.31  ...
# 4      Startup             57                        48.31  ...
#
#    productivity_change_percent  jobs_displaced jobs_created  \
# 0                         2.65               1            1
# ...

# %%
df_company.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150000 entries, 0 to 149999
# Data columns (total 43 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   response_id                  150000 non-null  int64
#  1   company_id                   150000 non-null  object
#  2   survey_year                  150000 non-null  int64
#  3   quarter                      150000 non-null  object
#  4   country                      150000 non-null  object
#  5   region                       150000 non-null  object
#  6   industry                     150000 non-null  object
#  7   company_size                 150000 non-null  object
#  8   num_employees                150000 non-null  int64
#  9   annual_revenue_usd_millions  150000 non-null  float64
#  10  company_founding_year        150000 non-null  int64
#  11  company_age                  150000 non-null  int64
# ...

# %%
df_company.isnull().sum()
# Out:
# response_id                    0
# company_id                     0
# survey_year                    0
# quarter                        0
# country                        0
# region                         0
# industry                       0
# company_size                   0
# num_employees                  0
# annual_revenue_usd_millions    0
# company_founding_year          0
# company_age                    0
# company_age_group              0
# ai_adoption_rate               0
# ai_adoption_stage              0
# years_using_ai                 0
# ai_primary_tool                0
# num_ai_tools_used              0
# ai_use_case                    0
# ai_projects_active             0
# ai_training_hours              0
# ai_budget_percentage           0
# ai_maturity_score              0
# ai_failure_rate                0
# ai_investment_per_employee     0
# regulatory_compliance_score    0
# data_privacy_level             0
# ai_ethics_committee            0
# ...

# %%
df_company.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_company.describe()
# Out:
#          response_id    survey_year  num_employees  \
# count  150000.000000  150000.000000  150000.000000
# mean    79961.106207    2024.500987    2342.376580
# std     46158.813039       1.118013    4754.424755
# min         1.000000    2023.000000      10.000000
# 25%     40020.750000    2024.000000      69.000000
# 50%     79937.500000    2025.000000     349.000000
# 75%    119913.250000    2026.000000     884.000000
# max    160000.000000    2026.000000   19970.000000
#
#        annual_revenue_usd_millions  company_founding_year    company_age  \
# count                150000.000000          150000.000000  150000.000000
# mean                   1180.345751            2005.993767      18.507220
# std                    2391.471420               9.473220       9.539367
# min                       1.010000            1990.000000       1.000000
# 25%                      33.880000            1998.000000      10.000000
# ...

# %%
df_company.describe(include = 'object')
# Out:
#         company_id quarter country  region    industry company_size  \
# count       150000  150000  150000  150000      150000       150000
# unique       10000       4      30       6           9            3
# top     COMP-09978      Q4  France    Asia  Technology          SME
# freq            16   37542    5637   49727       21107        63867
#
#        company_age_group ai_adoption_stage ai_primary_tool       ai_use_case  \
# count             150000            150000          150000            150000
# unique                 4                 4               6                 8
# top          16-30 years           partial         ChatGPT  Customer Support
# freq               68383             78800           46103             37683
#
#        data_privacy_level ai_ethics_committee  survey_source  \
# count              150000              150000         150000
# unique                  3                   2              4
# ...

# %%
df_company[['ai_adoption_rate', 'annual_revenue_usd_millions', 'productivity_change_percent']].corr()
# Out:
#                              ai_adoption_rate  annual_revenue_usd_millions  \
# ai_adoption_rate                     1.000000                     0.191219
# annual_revenue_usd_millions          0.191219                     1.000000
# productivity_change_percent          0.674973                     0.215749
#
#                              productivity_change_percent
# ai_adoption_rate                                0.674973
# annual_revenue_usd_millions                     0.215749
# productivity_change_percent                     1.000000

# %%
df_company['rev_per_employee'] = df_company['annual_revenue_usd_millions'] / df_company['num_employees']

# %%
df_company[['industry', 'rev_per_employee']].sort_values(by='rev_per_employee', ascending=False).head()
# Out:
#          industry  rev_per_employee
# 124964  Education          9.456657
# 124963  Education          9.456657
# 124955  Education          9.456657
# 124956  Education          9.456657
# 124957  Education          9.456657

# %%
# 1. List the columns we want to keep
golden_columns = [
    'company_id', 'country', 'region', 'industry', 'company_size', 
    'annual_revenue_usd_millions', 'num_employees', 'rev_per_employee',
    'ai_adoption_rate', 'ai_adoption_stage', 'productivity_change_percent',
    'survey_year', 'quarter'
]

# 2. Create a final dataframe with ONLY these columns
df_final = df_company[golden_columns]

# 3. EXPORT! This saves the file to your 'outputs' folder
df_final.to_csv('../outputs/AI_Adoption_Final_Clean.csv', index=False)

print("Success! Your cleaned file is ready in the outputs folder.")
# Out:
# Success! Your cleaned file is ready in the outputs folder.
